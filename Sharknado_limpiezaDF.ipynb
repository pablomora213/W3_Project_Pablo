# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import src.cleaning as cl

# %%
sharknado = pd.read_csv('data/attacks.csv',encoding="ISO-8859–1")
sharknado
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sharknado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
sharknado.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# href formula              19422
# href                      19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# Unnamed: 22               25722
# Unnamed: 23               25721
# dtype: int64

# %%
#Miramos y seleccionamos que variables(columnas) queremos tener
sharknados = sharknado[["Case Number", "Date", "Year","Type", "Country", "Area", "Activity", "Sex ", "Age", "Injury", "Fatal (Y/N)", "Species "]]
sharknados
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area     Activity Sex   Age  \
# 0           California     Paddling    F   57
# 1              Georgia     Standing    F   11
# 2               Hawaii      Surfing    M   48
# ...

# %%
#Modificamos los nombres de las variables para que podamos trabajar con facilidad
df = sharknados.copy()
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Activity',
#        'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Species '],
#       dtype='object')

# %%
renombre= [a.replace(" ", "_").lower() for a in df.columns]
renombre
# Out:
# ['case_number',
#  'date',
#  'year',
#  'type',
#  'country',
#  'area',
#  'activity',
#  'sex_',
#  'age',
#  'injury',
#  'fatal_(y/n)',
#  'species_']

# %%
df.columns= renombre
df
# Out:
#       case_number         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area     activity sex_  age  \
# 0           California     Paddling    F   57
# 1              Georgia     Standing    F   11
# 2               Hawaii      Surfing    M   48
# ...

# %%
df.rename(columns={'case_number': 'case', 'sex_': 'sex', "fatal_(y/n)": "dead", "species_": "especie" }, inplace=True)
df
# Out:
#              case         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area     activity  sex  age  \
# 0           California     Paddling    F   57
# 1              Georgia     Standing    F   11
# 2               Hawaii      Surfing    M   48
# ...

# %%
str(df['age'][3]).lower()
# Out:
# 'nan'

# %%
df["resolucion"]= df.injury.apply(cl.resolucion)
df
# Out:
#              case         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area     activity  sex  age  \
# 0           California     Paddling    F   57
# 1              Georgia     Standing    F   11
# 2               Hawaii      Surfing    M   48
# ...

# %%
#miramos tamaño para hacer dos tablas con las que trabajaremos, con nan y sin nan
df.shape
# Out:
# (25723, 13)

# %%
df["genre"]= df.sex.apply(cl.sexo)
df
# Out:
#              case         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area     activity  sex  age  \
# 0           California     Paddling    F   57
# 1              Georgia     Standing    F   11
# 2               Hawaii      Surfing    M   48
# ...

# %%
df.to_csv('sharky.csv', index = False)
#exportamos como csv

# %%
df.shape
# Out:
# (25723, 14)

# %%
sinan= df.dropna(how="all", axis=0)
#quitamos las filas en donde todo es nan

# %%
sinan
# Out:
#              case         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   area     activity  sex  age  \
# 0           California     Paddling    F   57
# 1              Georgia     Standing    F   11
# 2               Hawaii      Surfing    M   48
# ...

# %%
sinan.genre.value_counts()
# Out:
# m    5096
# f     637
# Name: genre, dtype: int64

# %%
sinan.dead.value_counts()
# Out:
# N          4293
# Y          1388
# UNKNOWN      71
#  N            7
# M             1
# 2017          1
# N             1
# y             1
# Name: dead, dtype: int64

# %%
sinan["deaths"]= df.dead.apply(cl.deaths)
sinan
# Out:
# <ipython-input-21-3bc93d8f2eb4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sinan["deaths"]= df.dead.apply(cl.deaths)
#              case         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# ...

# %%
sinan.deaths.value_counts()
# Out:
# 0.0    4373
# 1.0    1390
# Name: deaths, dtype: int64

# %%
sinan.especie.value_counts()
# Out:
# White shark                                                                                                                      163
# Shark involvement prior to death was not confirmed                                                                               105
# Invalid                                                                                                                          102
# Shark involvement not confirmed                                                                                                   88
# Tiger shark                                                                                                                       73
#                                                                                                                                 ...
# 1.2 m to 1.5 m [4.5' to 5'] shark                                                                                                  1
# ...

# %%
tibus=list(sinan.especie.unique())
tibus
#así analizo cuales son los mas habituales para la siguiente funcion
# Out:
# ['White shark',
#  nan,
#  '2 m shark',
#  'Tiger shark, 3m',
#  'Tiger shark',
#  "Lemon shark, 3'",
#  "Bull shark, 6'",
#  'Grey reef shark',
#  'Invalid incident',
#  'Tawny nurse shark, 2m',
#  'Shark involvement not confirmed',
#  'Questionable',
#  '3 m shark',
#  'White shark, 3.5 m',
#  'White shark, 2.5 m',
#  "6' shark",
#  'Juvenile bull shark',
#  'Bull shark',
#  "Tiger shark, 12'",
#  'Wobbegong shark',
#  '3.5 m shark',
#  '1.8 m shark',
#  'Blacktip shark',
#  'Juvenile white shark,  2.7 to 3.2 m',
#  'Bull shark, 2 m',
#  'Possibly a wobbegong',
#  'Injury believed caused by an eel, not a shark',
#  'Galapagos shark?',
#  '2m shark',
#  'Bull shark, 3 m ',
#  'Grey reef shark. 2 m',
#  'small shark',
#  'Wobbegong shark?',
#  'Juvenile nurse shark',
#  "Nurse shark. 5'",
#  'Tiger shark, female',
#  'Some drowned but other may have been killed by blue sharks',
#  'White shark, 4.6 m',
#  'Cookiecutter shark',
#  'Wobbegong shark, 1 m',
#  'White shark, 4.5 m',
# ...

# %%
sinan["sharktype"]= df.especie.apply(cl.sharks)
sinan
# Out:
# <ipython-input-25-482ec73ef67e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sinan["sharktype"]= df.especie.apply(cl.sharks)
#              case         date    year        type    country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# ...

# %%
sinan.sharktype.value_counts()
# Out:
# other         2290
# whiteshark     635
# tigershark     276
# bullshark      187
# hammer          48
# whitetip        28
# Name: sharktype, dtype: int64

# %%
deathstype= sinan[["resolucion", "genre", "deaths", "sharktype"]]
deathstype
# Out:
#       resolucion genre  deaths   sharktype
# 0      no injury     f     0.0  whiteshark
# 1           bite     f     0.0         NaN
# 2           bite     m     0.0         NaN
# 3           bite     m     0.0       other
# 4           bite     m     0.0  tigershark
# ...          ...   ...     ...         ...
# 8698         NaN   NaN     NaN         NaN
# 8699         NaN   NaN     NaN         NaN
# 8700         NaN   NaN     NaN         NaN
# 8701         NaN   NaN     NaN         NaN
# 25722        NaN   NaN     NaN         NaN
#
# [8703 rows x 4 columns]

# %%
deathstype= deathstype.dropna(how="all", axis=0)

# %%
whity = deathstype[deathstype.sharktype=="whiteshark"]
whity
# Out:
#      resolucion genre  deaths   sharktype
# 0     no injury     f     0.0  whiteshark
# 22    no injury     m     0.0  whiteshark
# 24    no injury     m     0.0  whiteshark
# 34         bite     m     0.0  whiteshark
# 40         bite     f     0.0  whiteshark
# ...         ...   ...     ...         ...
# 6162       bite     m     0.0  whiteshark
# 6172        NaN     m     0.0  whiteshark
# 6244       bite     m     0.0  whiteshark
# 6245       bite     f     0.0  whiteshark
# 6274  no injury     m     0.0  whiteshark
#
# [635 rows x 4 columns]

# %%
deathstype
# Out:
#      resolucion genre  deaths   sharktype
# 0     no injury     f     0.0  whiteshark
# 1          bite     f     0.0         NaN
# 2          bite     m     0.0         NaN
# 3          bite     m     0.0       other
# 4          bite     m     0.0  tigershark
# ...         ...   ...     ...         ...
# 6297      death     m     1.0         NaN
# 6298      death     m     1.0         NaN
# 6299      death     m     1.0         NaN
# 6300      death     m     1.0         NaN
# 6301      death     m     1.0         NaN
#
# [6302 rows x 4 columns]
